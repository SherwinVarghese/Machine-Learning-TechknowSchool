# %% [markdown]
# # Exploratory data analysis (EDA) - Assignment

# %% [markdown]
# ## Iris Flower dataset

# %% [markdown]
# Toy  Dataset: Iris Dataset: [https://en.wikipedia.org/wiki/Iris_flower_data_set]
# * A simple dataset to learn the basics.
# * 3 flowers of Iris species. [see images on wikipedia link above]
# * 1936 by Ronald Fisher.
# * Petal and Sepal: http://terpconnect.umd.edu/~petersd/666/html/iris_with_labels.jpg
# *  Objective: Classify a new flower as belonging to one of the 3 classes given the 4 features.
# * Importance of domain knowledge.
# * Why use petal and sepal dimensions as features?
# * Why do we not use 'color' as a feature?

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


'''downlaod iris.csv from https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'''
#Load Iris.csv into a pandas dataFrame.
iris = pd.read_csv("iris.csv")

# %%
# (Q) how many data-points and features are there in the dataset ?
# Out:
# (150, 5)

# %%
#(Q) What are the column names in our dataset?
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#(Q) How many data points for each class are present? 
#(or) How many flowers for each species are present?

#(Q) Is it a balanced-dataset or imbalanced dataset ?
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %% [markdown]
# # (3.2) 2-D Scatter Plot

# %%
#(Q) Draw a 2-D scatter plot of dataset
#Note: ALWAYS understand the axis: labels and scale.

# %% [markdown]
# Observations:
# 1. cannot make much sense out it.
# 2. What if we color the points by thier class-label/flower-type.

# %%
#(Q) Draw a 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn.
# Out:
# C:\Users\i329382\AppData\Local\Continuum\anaconda3\envs\tks\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Observation(s):**
# 1. Using sepal_length and sepal_width features, we can distinguish Setosa flowers from others.
# 2. Seperating Versicolor from Viginica is much harder as they have considerable overlap.

# %% [markdown]
# ## 3D Scatter plot
#
# https://plot.ly/pandas/3d-scatter-plots/
#
# Needs a lot to mouse interaction to interpret data.
#
# What about 4-D, 5-D or n-D scatter plot?

# %% [markdown]
# #  (3.3) Pair-plot

# %%
#(Q) Draw a pairwise scatter plot: Pair-Plot
# Out:
# C:\Users\i329382\AppData\Local\Continuum\anaconda3\envs\tks\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Dis-advantages:
# 1. Can be used when number of features are high.
# 2. Cannot visualize higher dimensional patterns in 3-D and 4-D.
# 3. Only possible to view 2D patterns.

# %% [markdown]
# **Observations**
# 1. petal_length and petal_width are the most useful features to identify various flower types.
# 2. While Setosa can be easily identified (linearly seperable), Virnica and Versicolor have some overlap (almost linearly seperable).
# 3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %% [markdown]
# # (3.4) Histogram, PDF, CDF

# %%
# (Q) Draw a seaborn plot to visualize the petal length for different species using facet grid and map functions
# Out:
# C:\Users\i329382\AppData\Local\Continuum\anaconda3\envs\tks\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# (Q) Draw a seaborn plot to visualize the petal width for different species using facet grid and map functions
# Out:
# C:\Users\i329382\AppData\Local\Continuum\anaconda3\envs\tks\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # (3.5) Mean  and Std-dev

# %%
#Mean, Variance, Std-deviation,  
print("Mean:")
print("iris setosa petal_length Mean: ", )
print("iris virginica petal_length Mean: ", )
print("iris versicolor petal_length Mean: ", )

print("\nStd-dev:")
print("iris setosa petal_length std deviantion: ", )
print("iris virginica petal_length std deviantion: ", )
print("iris versicolor petal_length std deviantion: ", )
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.5520000000000005
# 4.26
#
# Std-dev:
# 0.17176728442867112
# 0.546347874526844
# 0.4651881339845203

# %% [markdown]
# # (3.6) Median, Percentile, Quantile, IQR, MAD

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print("iris setosa petal_length median: ", ?)
print("iris virginica petal_length median: ", ?)
print("iris versicolor petal_length median: ", ?)


print("\nQuantiles:")
print("iris setosa petal_length Quantiles: ", np.percentile(iris_setosa["petal_length"],np.arange(0, 100, 25)))
print("iris virginica petal_length Quantiles: ", ?)
print("iris versicolor petal_length Quantiles: ", ?)

print("\n90th Percentiles:")
print("iris setosa petal_length 90th Percentile: ", np.percentile(iris_setosa["petal_length"],90))
print("iris virginica petal_length 90th Percentile: ", ?)
print("iris versicolor petal_length 90th Percentile: ", ?)

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print("Median Absolute Deviation for Iris Setosa petal length :", robust.mad(iris_setosa["petal_length"]))
print("Median Absolute Deviation for Iris virginica petal length :", )
print("Median Absolute Deviation for Iris versicolor petal length :", )
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.3100000000000005
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # (3.7) Box plot and Whiskers

# %%
#(Q) Generate a box plot for Iris species with x-axis as species and y-axis as petal_length

# %% [markdown]
# # (3.8) Violin plots

# %%
#(Q) Generate a violin plot for Iris species with x-axis as species and y-axis as petal_length

# %% [markdown]
# # (3.11) Multivariate probability density, contour plot.

# %%
#(Q) Generate a 2D Densse plot for Iris species with x-axis as petal_length and y-axis as petal_width for iris_setosa

# %% [markdown]
# # (3.12) Exercise:
#
# 1. Download Haberman Cancer Survival dataset from Kaggle. You may have to create a Kaggle account to donwload data. (https://www.kaggle.com/gilsousa/habermans-survival-data-set)
# 2. Perform a similar alanlaysis as above on this dataset with the following sections:
# * High level statistics of the dataset: number of points, numer of   features, number of classes, data-points per class.
# * Explain our objective.
# * Perform Univaraite analysis(PDF, CDF, Boxplot, Voilin plots) to understand which features are useful towards classification.
# * Perform Bi-variate analysis (scatter plots, pair-plots) to see if combinations of features are useful in classfication.
# * Write your observations in english as crisply and unambigously as possible. Always quantify your results.

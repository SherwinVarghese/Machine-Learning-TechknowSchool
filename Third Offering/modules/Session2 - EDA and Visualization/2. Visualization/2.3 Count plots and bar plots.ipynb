# %% [markdown]
# ## 2.3 Count plots and bar plots

# %% [markdown]
# ### 2.3.1 countplot() vs. catplot()

# %% [markdown]
# #### 2.3.1.1 countplot()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
masculinity_data = pd.read_csv("https://drive.google.com/uc?export=view&id=1cnN5ldi39rgDhyk2Mnsd_ICND6jlGaO6")
sns.countplot(x="how_masculine",
data=masculinity_data)
plt.show()

# %% [markdown]
# #### 2.3.1.2 catplot()

# %%
sns.catplot(x="how_masculine",
data=masculinity_data,
kind="count")
plt.show()

# %% [markdown]
# ### 2.3.2 Changing the order

# %%
category_order = ["No answer",
"Not at all",
"Not very",
"Somewhat",
"Very"]
sns.catplot(x="how_masculine",
data=masculinity_data,
kind="count",
order=category_order)
plt.show()

# %% [markdown]
# ### 2.3.3 Bar plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
sns.catplot(x="day",
y="total_bill",
data=tips,
kind="bar")
plt.show()

# %% [markdown]
# #### 2.3.3.1 Turning off confidence intervals

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
sns.catplot(x="day",
y="total_bill",
data=tips,
kind="bar",
ci=None)
plt.show()

# %% [markdown]
# ### 2.3.4 Changing the orientation

# %%
sns.catplot(x="total_bill",
y="day",
data=tips,
kind="bar")
plt.show()

# %% [markdown]
# ### 2.3.5 Box Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
g = sns.catplot(x="time",
y="total_bill",
data=tips,
kind="box")
plt.show()

# %% [markdown]
# ### 2.3.6 Change the order of categories

# %%
g = sns.catplot(x="time",
y="total_bill",
data=tips,
kind="box",
order=["Dinner",
"Lunch"])
plt.show()

# %% [markdown]
# ### 2.3.7 Omitting the outliers using `sym`

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
g = sns.catplot(x="time",
y="total_bill",
data=tips,
kind="box",
sym="")
plt.show()

# %% [markdown]
# ### 2.3.8 Changing the whiskers using `whis`

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
g = sns.catplot(x="time",
y="total_bill",
data=tips,
kind="box",
whis=[0, 100])
plt.show()

# %% [markdown]
# ### 2.3.9 Point plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
sns.catplot(x="smoker",
y="total_bill",
data=tips,
hue="sex", #'size',
kind="point")
plt.show()
